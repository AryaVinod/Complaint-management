# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('311_Service_Requests_from_2010_to_Present_min.csv')

# %%
data
# Out:
#          Unnamed: 0  Unique Key            Created Date  \
# 0                 0    45531130  02/02/2020 06:09:17 AM
# 1                 1    45529784  02/02/2020 02:15:24 PM
# 2                 2    45527528  02/02/2020 02:27:41 AM
# 3                 3    45530329  02/02/2020 12:13:18 PM
# 4                 4    45528814  02/02/2020 01:59:44 PM
# ...             ...         ...                     ...
# 6019838     6019838    44063685  10/15/2019 10:35:45 AM
# 6019839     6019839    44063692  10/15/2019 06:09:28 AM
# 6019840     6019840    44063724  10/15/2019 10:54:45 AM
# 6019841     6019841    44063726  10/15/2019 02:07:34 PM
# 6019842     6019842    44063737  10/15/2019 11:29:01 AM
#
#                     Closed Date        Complaint Type         Location Type  \
# 0                           NaN        HEAT/HOT WATER  RESIDENTIAL BUILDING
# 1                           NaN  UNSANITARY CONDITION  RESIDENTIAL BUILDING
# ...

# %%
df=data[['Unique Key','Created Date','Closed Date','Complaint Type','Borough']]
df.head()
# Out:
#    Unique Key            Created Date Closed Date        Complaint Type  \
# 0    45531130  02/02/2020 06:09:17 AM         NaN        HEAT/HOT WATER
# 1    45529784  02/02/2020 02:15:24 PM         NaN  UNSANITARY CONDITION
# 2    45527528  02/02/2020 02:27:41 AM         NaN        HEAT/HOT WATER
# 3    45530329  02/02/2020 12:13:18 PM         NaN        HEAT/HOT WATER
# 4    45528814  02/02/2020 01:59:44 PM         NaN             APPLIANCE
#
#      Borough
# 0  MANHATTAN
# 1   BROOKLYN
# 2     QUEENS
# 3      BRONX
# 4   BROOKLYN

# %%
x=df.sort_values(by=['Created Date'], inplace=False, ascending=True)

# %%
x.head()
# Out:
#         Unique Key            Created Date             Closed Date  \
# 177182    15634460  01/01/2010 02:31:13 PM  01/02/2010 02:35:01 PM
# 177179    15634698  01/01/2010 02:39:02 PM  01/04/2010 01:20:45 PM
# 177186    15633862  01/01/2010 04:18:46 PM  01/04/2010 01:20:46 PM
# 177188    15633410  01/01/2010 04:59:23 PM  01/02/2010 05:02:49 PM
# 177180    15634558  01/01/2010 05:00:01 AM  01/04/2010 01:20:48 PM
#
#                 Complaint Type      Borough
# 177182  HPD Literature Request  Unspecified
# 177179  HPD Literature Request  Unspecified
# 177186  HPD Literature Request  Unspecified
# 177188  HPD Literature Request  Unspecified
# 177180  HPD Literature Request  Unspecified

# %%
x.tail()
# Out:
#        Unique Key            Created Date             Closed Date  \
# 62668    45284115  12/31/2019 12:57:51 AM  12/31/2019 09:21:04 PM
# 76629    45281616  12/31/2019 12:58:50 PM                     NaN
# 6410     45284092  12/31/2019 12:59:01 PM  01/21/2020 09:01:40 AM
# 6764     45280065  12/31/2019 12:59:06 PM  01/10/2020 01:42:41 PM
# 76613    45282880  12/31/2019 12:59:12 PM  12/31/2019 04:24:32 PM
#
#        Complaint Type    Borough
# 62668  HEAT/HOT WATER   BROOKLYN
# 76629      WATER LEAK     QUEENS
# 6410          GENERAL  MANHATTAN
# 6764       WATER LEAK  MANHATTAN
# 76613  HEAT/HOT WATER      BRONX

# %%
data["Incident Address"].isnull().sum()
# Out:
# 52825

# %%
Bronx=pd.read_csv('BX_18v1.csv')
Bronx.head()
# Out:
# C:\Python\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,20,22,23,64,65,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      BX   2260    1  201    19.0  1022.0         7.0      8.0  10454.0
# 1      BX   2260    4  201    19.0  1022.0         7.0      8.0  10454.0
# 2      BX   2260   10  201    19.0  1022.0         7.0      8.0  10454.0
# 3      BX   2260   17  201    19.0  1022.0         7.0      8.0  10454.0
# 4      BX   2260   18  201    19.0  1022.0         7.0      8.0  10454.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum  APPBBL APPDate  \
# 0     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# 1     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# 2     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# ...

# %%
Bronx['ZipCode'].unique().shape
# Out:
# (27,)

# %%
Queens=pd.read_csv('QN_18v1.csv')
Queens.head()
# Out:
# C:\Python\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,20,22,23,64,65,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      QN      6    1  402     1.0     NaN        30.0     26.0  11101.0
# 1      QN      6    3  402     1.0  1015.0        30.0     26.0  11101.0
# 2      QN      6    8  402     1.0  1011.0        30.0     26.0  11101.0
# 3      QN      6   20  402     1.0     NaN        30.0     26.0  11101.0
# 4      QN      6   30  402     1.0     NaN        30.0     26.0  11101.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum        APPBBL  \
# 0     L115  ...       Y  401 011  40101.0        NaN  4.000060e+09
# 1     L115  ...     NaN  401 011  40101.0        NaN  0.000000e+00
# 2     L115  ...     NaN  401 011  40101.0        NaN  4.000060e+09
# ...

# %%
Queens['ZipCode'].unique().shape
# Out:
# (66,)

# %% [markdown]
# # Question 1
#
# ### Which type of complaint should the Department of Housing Preservation and Development of New York City focus on first?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019843 entries, 0 to 6019842
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unique Key      int64
#  1   Created Date    object
#  2   Closed Date     object
#  3   Complaint Type  object
#  4   Borough         object
# dtypes: int64(1), object(4)
# memory usage: 229.6+ MB

# %%
#unique complaint types
df["Complaint Type"].unique()
# Out:
# array(['HEAT/HOT WATER', 'UNSANITARY CONDITION', 'APPLIANCE', 'GENERAL',
#        'ELECTRIC', 'PLUMBING', 'PAINT/PLASTER', 'WATER LEAK', 'SAFETY',
#        'DOOR/WINDOW', 'OUTSIDE BUILDING', 'ELEVATOR', 'FLOORING/STAIRS',
#        'Unsanitary Condition', 'HPD Literature Request', 'HEATING',
#        'PAINT - PLASTER', 'Safety', 'Electric', 'General', 'Appliance',
#        'GENERAL CONSTRUCTION', 'NONCONST', 'CONSTRUCTION', 'AGENCY',
#        'STRUCTURAL', 'VACANT APARTMENT', 'Outside Building', 'Plumbing',
#        'Mold'], dtype=object)

# %%
df["Complaint Type"].unique().shape
# Out:
# (30,)

# %%
df["Complaint Type"].isnull().sum()
# Out:
# 0

# %%
df["Complaint Type"].value_counts().sum()
# Out:
# 6019843

# %%
#Plotting the complaint types to number occurance

import matplotlib.pyplot as plt

df["Complaint Type"].value_counts().plot(kind='bar', figsize=(10, 7))
#
plt.xlabel('Complaint Type') # add to x-label to the plot
plt.ylabel('Number occurance') # add y-label to the plot
plt.title('Complaints Distribution') # add title to the plot
#
plt.show()

# %%
df["Complaint Type"].value_counts()
# Out:
# HEAT/HOT WATER            1261574
# HEATING                    887850
# PLUMBING                   711130
# GENERAL CONSTRUCTION       500863
# UNSANITARY CONDITION       451643
# PAINT - PLASTER            361257
# PAINT/PLASTER              346438
# ELECTRIC                   307310
# NONCONST                   260890
# DOOR/WINDOW                205278
# WATER LEAK                 193631
# GENERAL                    151308
# FLOORING/STAIRS            137402
# APPLIANCE                  112831
# HPD Literature Request      52824
# SAFETY                      51529
# OUTSIDE BUILDING             7142
# ELEVATOR                     6725
# Unsanitary Condition         5499
# CONSTRUCTION                 5078
# General                      1163
# Safety                        424
# STRUCTURAL                     16
# Plumbing                       11
# AGENCY                          9
# VACANT APARTMENT                6
# Outside Building                6
# ...

# %% [markdown]
# ### Conclusion
# #### We see that the most number of complaints are from Heat/Hot Water type, with 1261574 complaints. Therefore, the Department of Housing Preservation and Development of New York City focus on Heat/Hot Water complaints first.

# %% [markdown]
# # Question 2
#
# ### Should the Department of Housing Preservation and Development of New York City focus on any particular set of boroughs, ZIP codes, or street (where the complaints are severe) for the specific type of complaints you identified in response to Question 1?

# %%
df=data[['Unique Key','Created Date','Closed Date','Complaint Type','Borough','Incident Zip','Incident Address','Street Name','Status']]

# %%
df2=df[df['Complaint Type'] == ('HEAT/HOT WATER')]
df2.head()
# Out:
#    Unique Key            Created Date Closed Date  Complaint Type    Borough  \
# 0    45531130  02/02/2020 06:09:17 AM         NaN  HEAT/HOT WATER  MANHATTAN
# 2    45527528  02/02/2020 02:27:41 AM         NaN  HEAT/HOT WATER     QUEENS
# 3    45530329  02/02/2020 12:13:18 PM         NaN  HEAT/HOT WATER      BRONX
# 5    45530344  02/02/2020 07:52:08 AM         NaN  HEAT/HOT WATER      BRONX
# 7    45527939  02/02/2020 09:00:54 AM         NaN  HEAT/HOT WATER     QUEENS
#
#    Incident Zip         Incident Address         Street Name Status
# 0       10019.0     426 WEST   52 STREET    WEST   52 STREET   Open
# 2       11372.0          87-15 37 AVENUE           37 AVENUE   Open
# 3       10458.0  2405 SOUTHERN BOULEVARD  SOUTHERN BOULEVARD   Open
# 5       10456.0       1131 MORRIS AVENUE       MORRIS AVENUE   Open
# 7       11372.0          37-20 81 STREET           81 STREET   Open

# %%
df2['Borough'].value_counts()
# Out:
# BRONX            410853
# BROOKLYN         384523
# MANHATTAN        285526
# QUEENS           168318
# STATEN ISLAND     12353
# Unspecified           1
# Name: Borough, dtype: int64

# %%
df2["Street Name"].value_counts().head()
# Out:
# GRAND CONCOURSE    22287
# BROADWAY           15368
# ELMHURST AVENUE    11377
# OCEAN AVENUE       10110
# MORRIS AVENUE       9727
# Name: Street Name, dtype: int64

# %%
df2.loc[df['Street Name'] == "GRAND CONCOURSE"].head()
# Out:
#      Unique Key            Created Date Closed Date  Complaint Type Borough  \
# 63     45527566  02/02/2020 11:56:06 PM         NaN  HEAT/HOT WATER   BRONX
# 68     45528450  02/02/2020 10:39:56 PM         NaN  HEAT/HOT WATER   BRONX
# 77     45531736  02/02/2020 10:49:43 PM         NaN  HEAT/HOT WATER   BRONX
# 78     45528908  02/02/2020 10:35:10 PM         NaN  HEAT/HOT WATER   BRONX
# 220    45529407  02/02/2020 10:35:02 PM         NaN  HEAT/HOT WATER   BRONX
#
#      Incident Zip      Incident Address      Street Name Status
# 63        10453.0  2095 GRAND CONCOURSE  GRAND CONCOURSE   Open
# 68        10458.0  2664 GRAND CONCOURSE  GRAND CONCOURSE   Open
# 77        10468.0  2715 GRAND CONCOURSE  GRAND CONCOURSE   Open
# 78        10453.0  2095 GRAND CONCOURSE  GRAND CONCOURSE   Open
# 220       10453.0  2095 GRAND CONCOURSE  GRAND CONCOURSE   Open

# %%
df2['Incident Zip'].value_counts()
# Out:
# 11226.0    41786
# 10458.0    38864
# 10467.0    38110
# 10468.0    34507
# 10453.0    34241
#            ...
# 10112.0        1
# 10121.0        1
# 10045.0        1
# 10129.0        1
# 12345.0        1
# Name: Incident Zip, Length: 191, dtype: int64

# %%
df2['Incident Address'].value_counts()
# Out:
# 89-21 ELMHURST AVENUE         10896
# 1025 BOYNTON AVENUE            5220
# 34 ARDEN STREET                4965
# 9511 SHORE ROAD                4587
# 2090 EAST TREMONT AVENUE       3615
#                               ...
# 4906 FT HAMILTON PARKWAY          1
# 2374 JEROME AVENUE                1
# 194-15 NASHVILLE BOULEVARD        1
# 476 BEACH   46 STREET             1
# 870 NOSTRAND AVENUE               1
# Name: Incident Address, Length: 97979, dtype: int64

# %%
df2['Status'].value_counts()
# Out:
# Closed     876455
# Open        11393
# Pending         2
# Name: Status, dtype: int64

# %% [markdown]
# ### Conclusion
# #### 1. The borough with the most number of heat/hot water complaints is BRONX with 410853 complaints.
# #### 2. The street with the most number of heat/hot water complaints is GRAND CONCOURSE with 22287 complaints.
# #### 3. The zip code with the most number of heat/hot water complaints is 11226 with 41786 complaints.
# #### Therefore, the Department of Housing Preservation and Development of New York City should focus on these for the heat/hot water complaints.

# %% [markdown]
# # Question 3
#
# ### Does the Complaint Type that you identified in response to question 1 have an obvious relationship with any particular characteristic or characteristics of the houses or buildings?

# %%
df_br = df[df['Borough'] == "BRONX"]
df_br.head()
# Out:
#     Unique Key            Created Date Closed Date        Complaint Type  \
# 3     45530329  02/02/2020 12:13:18 PM         NaN        HEAT/HOT WATER
# 5     45530344  02/02/2020 07:52:08 AM         NaN        HEAT/HOT WATER
# 10    45530349  02/02/2020 05:38:39 AM         NaN        HEAT/HOT WATER
# 16    45528878  02/02/2020 04:11:19 AM         NaN  UNSANITARY CONDITION
# 19    45529362  02/02/2020 01:38:25 PM         NaN        HEAT/HOT WATER
#
#    Borough  Incident Zip         Incident Address         Street Name Status
# 3    BRONX       10458.0  2405 SOUTHERN BOULEVARD  SOUTHERN BOULEVARD   Open
# 5    BRONX       10456.0       1131 MORRIS AVENUE       MORRIS AVENUE   Open
# 10   BRONX       10459.0        1032 ALDUS STREET        ALDUS STREET   Open
# 16   BRONX       10456.0     488 EAST  164 STREET    EAST  164 STREET   Open
# 19   BRONX       10473.0       880 BOYNTON AVENUE      BOYNTON AVENUE   Open

# %%
import numpy as np
df_br['Complaint Type'] = np.where(df_br['Complaint Type']=='HEATING','HEAT/HOT WATER',df_br['Complaint Type'])
# Out:
# C:\Python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_br["Complaint Type"].value_counts()
# Out:
# HEAT/HOT WATER          606133
# PLUMBING                179872
# UNSANITARY CONDITION    136843
# PAINT/PLASTER           115679
# GENERAL CONSTRUCTION    107868
# PAINT - PLASTER          79422
# ELECTRIC                 74037
# DOOR/WINDOW              66277
# WATER LEAK               62374
# NONCONST                 50599
# FLOORING/STAIRS          44540
# GENERAL                  41124
# APPLIANCE                33031
# SAFETY                   13668
# ELEVATOR                  1801
# Unsanitary Condition      1753
# OUTSIDE BUILDING          1580
# CONSTRUCTION               871
# General                    340
# Safety                     135
# STRUCTURAL                   4
# AGENCY                       3
# Plumbing                     2
# Name: Complaint Type, dtype: int64

# %% [markdown]
# Now we have Heating complaints and heat/hot water complaints merged.

# %%
df_brht = df_br[df_br['Complaint Type'] == ("HEAT/HOT WATER")]
df_brht.head()
# Out:
#     Unique Key            Created Date Closed Date  Complaint Type Borough  \
# 3     45530329  02/02/2020 12:13:18 PM         NaN  HEAT/HOT WATER   BRONX
# 5     45530344  02/02/2020 07:52:08 AM         NaN  HEAT/HOT WATER   BRONX
# 10    45530349  02/02/2020 05:38:39 AM         NaN  HEAT/HOT WATER   BRONX
# 19    45529362  02/02/2020 01:38:25 PM         NaN  HEAT/HOT WATER   BRONX
# 29    45528454  02/02/2020 10:25:32 PM         NaN  HEAT/HOT WATER   BRONX
#
#     Incident Zip          Incident Address          Street Name Status
# 3        10458.0   2405 SOUTHERN BOULEVARD   SOUTHERN BOULEVARD   Open
# 5        10456.0        1131 MORRIS AVENUE        MORRIS AVENUE   Open
# 10       10459.0         1032 ALDUS STREET         ALDUS STREET   Open
# 19       10473.0        880 BOYNTON AVENUE       BOYNTON AVENUE   Open
# 29       10463.0  3110 KINGSBRIDGE TERRACE  KINGSBRIDGE TERRACE   Open

# %%
Bronx_new = Bronx[["Address", "BldgArea", "BldgDepth", "BuiltFAR", "CommFAR",
             "FacilFAR", "Lot", "LotArea", "LotDepth", "NumBldgs", "NumFloors", 
             "OfficeArea", "ResArea", "ResidFAR", "RetailArea", "YearBuilt", 
             "YearAlter1", "ZipCode", "YCoord", "XCoord"]]
Bronx_new.head()
# Out:
#                   Address  BldgArea  BldgDepth  BuiltFAR  CommFAR  FacilFAR  \
# 0  122 BRUCKNER BOULEVARD         0        0.0      0.00      5.0       6.5
# 1  126 BRUCKNER BOULEVARD       752       16.0      0.05      5.0       6.5
# 2  138 BRUCKNER BOULEVARD     39375      200.0      1.13      5.0       6.5
# 3  144 BRUCKNER BOULEVARD     12500       85.0      5.00      5.0       6.5
# 4  148 BRUCKNER BOULEVARD      8595       70.0      4.58      5.0       6.5
#
#    Lot  LotArea  LotDepth  NumBldgs  NumFloors  OfficeArea  ResArea  ResidFAR  \
# 0    1    15000     200.0         1        0.0           0        0      6.02
# 1    4    13770     100.0         2        1.0         272        0      6.02
# 2   10    35000     200.0         1        2.0           0        0      6.02
# 3   17     2500     100.0         1        5.0           0    12500      6.02
# 4   18     1875      75.0         1        5.0           0     6876      6.02
#
# ...

# %% [markdown]
# Merging by address

# %%
df_brht.dropna(subset = ["Incident Address"], axis = 0, inplace=True)
df_brht["Incident Address"].isnull().sum()
# Out:
# C:\Python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0

# %%
bronx_incidents = df_brht[["Incident Address", "Complaint Type"]]

# %%
table = bronx_incidents.groupby(["Incident Address"])
table.head()
# Out:
#                  Incident Address  Complaint Type
# 3         2405 SOUTHERN BOULEVARD  HEAT/HOT WATER
# 5              1131 MORRIS AVENUE  HEAT/HOT WATER
# 10              1032 ALDUS STREET  HEAT/HOT WATER
# 19             880 BOYNTON AVENUE  HEAT/HOT WATER
# 29       3110 KINGSBRIDGE TERRACE  HEAT/HOT WATER
# ...                           ...             ...
# 6019175     1535 MAYFLOWER AVENUE  HEAT/HOT WATER
# 6019509     1509 EAST  172 STREET  HEAT/HOT WATER
# 6019525        2860 LAMPORT PLACE  HEAT/HOT WATER
# 6019617  2002 GILDERSLEEVE AVENUE  HEAT/HOT WATER
# 6019681          2248 RYER AVENUE  HEAT/HOT WATER
#
# [76594 rows x 2 columns]

# %%
bx_final = table.count()
bx_final.columns = ["Total Complaints"]

# %%
Bronx_new.drop_duplicates(subset="Address", keep=False, inplace=True)
# Out:
# C:\Python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Bronx_new['Address'].value_counts().head()
# Out:
# 1311 COLLEGE AVENUE    1
# 1421 LELAND AVENUE     1
# 1550 MINFORD PLACE     1
# 2425 YATES AVENUE      1
# 1040 METCALF AVENUE    1
# Name: Address, dtype: int64

# %%
merged = pd.merge(bx_final, Bronx_new, left_index=True, right_on="Address", how="right")
merged.head()
# Out:
#    Total Complaints                 Address  BldgArea  BldgDepth  BuiltFAR  \
# 0               NaN  122 BRUCKNER BOULEVARD         0        0.0      0.00
# 1               NaN  126 BRUCKNER BOULEVARD       752       16.0      0.05
# 2               NaN  138 BRUCKNER BOULEVARD     39375      200.0      1.13
# 3               5.0  144 BRUCKNER BOULEVARD     12500       85.0      5.00
# 4              13.0  148 BRUCKNER BOULEVARD      8595       70.0      4.58
#
#    CommFAR  FacilFAR  Lot  LotArea  LotDepth  ...  NumFloors  OfficeArea  \
# 0      5.0       6.5    1    15000     200.0  ...        0.0           0
# 1      5.0       6.5    4    13770     100.0  ...        1.0         272
# 2      5.0       6.5   10    35000     200.0  ...        2.0           0
# 3      5.0       6.5   17     2500     100.0  ...        5.0           0
# 4      5.0       6.5   18     1875      75.0  ...        5.0           0
#
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86348 entries, 0 to 89847
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Total Complaints  17311 non-null  float64
#  1   Address           86348 non-null  object
#  2   BldgArea          86348 non-null  int64
#  3   BldgDepth         86348 non-null  float64
#  4   BuiltFAR          86348 non-null  float64
#  5   CommFAR           86348 non-null  float64
#  6   FacilFAR          86348 non-null  float64
#  7   Lot               86348 non-null  int64
#  8   LotArea           86348 non-null  int64
#  9   LotDepth          86348 non-null  float64
#  10  NumBldgs          86348 non-null  int64
#  11  NumFloors         86348 non-null  float64
#  12  OfficeArea        86348 non-null  int64
#  13  ResArea           86348 non-null  int64
#  14  ResidFAR          86348 non-null  float64
#  15  RetailArea        86348 non-null  int64
# ...

# %%
merged["HOT/HEAT WATER"] = merged["Total Complaints"]
merged.head()
# Out:
#    Total Complaints                 Address  BldgArea  BldgDepth  BuiltFAR  \
# 0               NaN  122 BRUCKNER BOULEVARD         0        0.0      0.00
# 1               NaN  126 BRUCKNER BOULEVARD       752       16.0      0.05
# 2               NaN  138 BRUCKNER BOULEVARD     39375      200.0      1.13
# 3               5.0  144 BRUCKNER BOULEVARD     12500       85.0      5.00
# 4              13.0  148 BRUCKNER BOULEVARD      8595       70.0      4.58
#
#    CommFAR  FacilFAR  Lot  LotArea  LotDepth  ...  OfficeArea  ResArea  \
# 0      5.0       6.5    1    15000     200.0  ...           0        0
# 1      5.0       6.5    4    13770     100.0  ...         272        0
# 2      5.0       6.5   10    35000     200.0  ...           0        0
# 3      5.0       6.5   17     2500     100.0  ...           0    12500
# 4      5.0       6.5   18     1875      75.0  ...           0     6876
#
#    ResidFAR  RetailArea  YearBuilt  YearAlter1  ZipCode    YCoord     XCoord  \
# ...

# %%
merged["HOT/HEAT WATER"].replace(np.nan, 0.0, inplace = True)
merged['HOT/HEAT WATER'] = np.where(merged['HOT/HEAT WATER'] >  0, True, False)
merged["HOT/HEAT WATER"].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: HOT/HEAT WATER, dtype: bool

# %%
merged["Total Complaints"].replace(np.nan, 0.0, inplace = True)

# %%
merged.loc[merged['YearBuilt'] == 0]
# Out:
#        Total Complaints                 Address  BldgArea  BldgDepth  \
# 0                   0.0  122 BRUCKNER BOULEVARD         0        0.0
# 8                   0.0          LINCOLN AVENUE         0        0.0
# 13                  0.0     180 EAST 132 STREET         0        0.0
# 15                  0.0      500 ST ANNS AVENUE         0        0.0
# 20                  0.0     510 EAST 134 STREET         0        0.0
# ...                 ...                     ...       ...        ...
# 89751               0.0     620 WEST 256 STREET      7500        0.0
# 89752               0.0     622 WEST 256 STREET         0        0.0
# 89795               0.0         RIVERCREST ROAD         0        0.0
# 89844               0.0    755 RIVERDALE AVENUE         0        0.0
# 89847               0.0             GOLD STREET         0        0.0
#
#        BuiltFAR  CommFAR  FacilFAR  Lot  LotArea  LotDepth  ...  OfficeArea  \
# ...

# %%
import datetime as dt
today=dt.datetime.now().date()

# %%
merged['YCoord'] = merged.YCoord.fillna('00.000').astype(float)
merged['XCoord'] = merged.XCoord.fillna('00.000').astype(float) 
merged.head(100)
# Out:
#      Total Complaints                 Address  BldgArea  BldgDepth  BuiltFAR  \
# 0                 0.0  122 BRUCKNER BOULEVARD         0        0.0      0.00
# 1                 0.0  126 BRUCKNER BOULEVARD       752       16.0      0.05
# 2                 0.0  138 BRUCKNER BOULEVARD     39375      200.0      1.13
# 3                 5.0  144 BRUCKNER BOULEVARD     12500       85.0      5.00
# 4                13.0  148 BRUCKNER BOULEVARD      8595       70.0      4.58
# ..                ...                     ...       ...        ...       ...
# 100               0.0     526 EAST 139 STREET      1480       40.0      0.80
# 101               0.0     528 EAST 139 STREET      1480       40.0      0.80
# 102               4.0     550 EAST 139 STREET     11405       95.0      4.56
# 103               0.0      227 ST ANNS AVENUE         0        0.0      0.00
# 104              16.0      225 ST ANNS AVENUE     11568       82.0      4.54
#
# ...

# %%
merged.isnull().sum()
# Out:
# Total Complaints     0
# Address              0
# BldgArea             0
# BldgDepth            0
# BuiltFAR             0
# CommFAR              0
# FacilFAR             0
# Lot                  0
# LotArea              0
# LotDepth             0
# NumBldgs             0
# NumFloors            0
# OfficeArea           0
# ResArea              0
# ResidFAR             0
# RetailArea           0
# YearBuilt            0
# YearAlter1           0
# ZipCode             17
# YCoord               0
# XCoord               0
# HOT/HEAT WATER       0
# dtype: int64

# %%
merged['ZipCode'] = merged.ZipCode.fillna('00.000').astype(float)
merged.isnull().sum()
# Out:
# Total Complaints    0
# Address             0
# BldgArea            0
# BldgDepth           0
# BuiltFAR            0
# CommFAR             0
# FacilFAR            0
# Lot                 0
# LotArea             0
# LotDepth            0
# NumBldgs            0
# NumFloors           0
# OfficeArea          0
# ResArea             0
# ResidFAR            0
# RetailArea          0
# YearBuilt           0
# YearAlter1          0
# ZipCode             0
# YCoord              0
# XCoord              0
# HOT/HEAT WATER      0
# dtype: int64

# %%
import scipy.stats as stats

# %%
merged.corr(method="pearson")
# Out:
#                   Total Complaints  BldgArea  BldgDepth  BuiltFAR   CommFAR  \
# Total Complaints          1.000000  0.073841   0.145417  0.151354 -0.007360
# BldgArea                  0.073841  1.000000   0.251595  0.282479  0.043317
# BldgDepth                 0.145417  0.251595   1.000000  0.265879  0.197150
# BuiltFAR                  0.151354  0.282479   0.265879  1.000000  0.030932
# CommFAR                  -0.007360  0.043317   0.197150  0.030932  1.000000
# FacilFAR                  0.118762  0.095249   0.280294  0.258514  0.226466
# Lot                      -0.000848  0.080686   0.006221  0.112895  0.006924
# LotArea                   0.003906  0.271776   0.057733 -0.004659  0.018106
# LotDepth                  0.024704  0.310508   0.328900 -0.005842  0.102388
# NumBldgs                 -0.006673  0.600347   0.069807  0.093692 -0.008253
# NumFloors                 0.227028  0.364794   0.367817  0.441218 -0.050606
# ...

# %% [markdown]
# ### Conclusion
# #### We see a reasonable yet not so strong correlation between the number of floors of the building and the heat/hot water complaint type
